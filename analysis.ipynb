# %%
from pathlib import Path
import warnings
import pandas as pd
import seaborn as sns

BASE_DIR = Path().resolve()


with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=FutureWarning)
    from youtube import DatabaseConnection

with DatabaseConnection(db_path=BASE_DIR / 'data' / 'sqlite.db') as db:
    videos_dataframe = db.videos_to_dataframe()
    comments_dataframe = db.comments_to_dataframe()

# %% [markdown]
# # Videos

# %%
display(videos_dataframe.info(memory_usage='deep'))
display(videos_dataframe)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    28 non-null     object
#  1   publishedAt           28 non-null     object
#  2   channelId             28 non-null     object
#  3   title                 28 non-null     object
#  4   description           28 non-null     object
#  5   thumbnails            28 non-null     object
#  6   channelTitle          28 non-null     object
#  7   tags                  28 non-null     object
#  8   categoryId            28 non-null     object
#  9   liveBroadcastContent  28 non-null     object
#  10  defaultLanguage       28 non-null     object
#  11  localized             28 non-null     object
#  12  defaultAudioLanguage  28 non-null     object
# dtypes: object(13)
# memory usage: 125.4 KB
# None
# ...

# %% [markdown]
# # Comments

# %%
display(comments_dataframe.info(memory_usage='deep'))
display(comments_dataframe)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308972 entries, 0 to 308971
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     308972 non-null  object
#  1   channelId              308972 non-null  object
#  2   videoId                308972 non-null  object
#  3   textDisplay            308972 non-null  object
#  4   textOriginal           308972 non-null  object
#  5   parentId               55908 non-null   object
#  6   authorDisplayName      308972 non-null  object
#  7   authorProfileImageUrl  308972 non-null  object
#  8   authorChannelUrl       308972 non-null  object
#  9   authorChannelId        308972 non-null  object
#  10  canRate                308972 non-null  int64
#  11  viewerRating           308972 non-null  object
#  12  likeCount              308972 non-null  int64
#  13  publishedAt            308972 non-null  object
# ...

# %% [markdown]
# # Analysis
